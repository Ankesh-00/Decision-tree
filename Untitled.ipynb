# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pt

# %%
df=pd.read_csv("penguins_size.csv")

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df=df.dropna()   #remove null values in row

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            334 non-null    object
#  1   island             334 non-null    object
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.9+ KB

# %%
df["sex"].unique()
# Out:
# array(['MALE', 'FEMALE', '.'], dtype=object)

# %%
df=df[df["sex"]!="."]

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %% [markdown]
# # Visualization

# %%
sns.scatterplot(x="culmen_length_mm",y="culmen_depth_mm",hue="species",data=df,palette="Dark2")
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %%
sns.pairplot(data=df,hue="species")
# Out:
# C:\Users\avich\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x="species",y="culmen_length_mm",data=df,kind="box",hue="sex")
# Out:
# C:\Users\avich\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x="species",y="culmen_depth_mm",data=df,kind="box",hue="sex")
# Out:
# C:\Users\avich\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Feature Engineering

# %%
pd.get_dummies(df,dtype=int)
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 4                36.7             19.3              193.0       3450.0
# 5                39.3             20.6              190.0       3650.0
# ..                ...              ...                ...          ...
# 338              47.2             13.7              214.0       4925.0
# 340              46.8             14.3              215.0       4850.0
# 341              50.4             15.7              222.0       5750.0
# 342              45.2             14.8              212.0       5200.0
# 343              49.9             16.1              213.0       5400.0
#
#      species_Adelie  species_Chinstrap  species_Gentoo  island_Biscoe  \
# ...

# %%
x = pd.get_dummies(df.drop('species',axis=1),drop_first=True)
y=df["species"]

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=101)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decision=DecisionTreeClassifier()

# %%
decision.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=decision.predict(x_test)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import confusion_matrix,classification_report,confusion_matrix

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[23,  1,  0],
#        [ 0, 12,  0],
#        [ 1,  0, 13]], dtype=int64)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       0.96      0.96      0.96        24
#    Chinstrap       0.92      1.00      0.96        12
#       Gentoo       1.00      0.93      0.96        14
#
#     accuracy                           0.96        50
#    macro avg       0.96      0.96      0.96        50
# weighted avg       0.96      0.96      0.96        50

# %%
decision.feature_importances_
# Out:
# array([0.3662955 , 0.04135396, 0.53882733, 0.        , 0.03134626,
#        0.        , 0.02217695])

# %%
pd.DataFrame(index=x.columns,data=decision.feature_importances_,columns=['Feature Importance'])
# Out:
#                    Feature Importance
# culmen_length_mm             0.366295
# culmen_depth_mm              0.041354
# flipper_length_mm            0.538827
# body_mass_g                  0.000000
# island_Dream                 0.031346
# island_Torgersen             0.000000
# sex_MALE                     0.022177

# %%
sns.boxplot(x='species',y='body_mass_g',data=df)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# # Visualize the Tree

# %%
from sklearn.tree import plot_tree

# %%
pt.figure(figsize=(12,8))
plot_tree(decision);
